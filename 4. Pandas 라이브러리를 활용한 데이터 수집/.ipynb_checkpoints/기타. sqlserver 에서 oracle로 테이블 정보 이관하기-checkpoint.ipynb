# %% [markdown]
# ### 아래 구성도를 활용하여 sqlserver -> 오라클로 KOPO_PRODUCT_VOLUME 테이블 정보를 이관하세요 (단, VOLUME을 제외한 컬럼에 _{이니셜} 로 컬럼명을 변경하고 오라클 테이블 저장이름은 KOPO_PRODUCT_VOLUME_ST_학생명) 으로 지정하세요.

# %%
# PANDAS 패키지 불러오기
import pandas as pd
import pymssql
from sqlalchemy import create_engine

# DB 커넥션 열기
engine = create_engine('mssql+pymssql://haiteam:kopo1234!@192.168.110.107:1433/kopo')

# %%
# DB 테이블을 읽어 Data Frame 변수에 저장하기
pdVariable = pd.read_sql_query('SELECT * FROM KOPO_PRODUCT_VOLUME', engine)

# %%
# 컬럼해더 재정의
pdVariable.columns = ['REDIONID_KJS','PRODUCTGROUP_KJS','YEARWEEK_KJS','VOLUME']

# %%
# 데이터 VIEW
pdVariable
# Out:
#     REDIONID_KJS PRODUCTGROUP_KJS YEARWEEK_KJS   VOLUME
# 0            A01           ST0001       201501   513598
# 1            A01           ST0001       201502   438251
# 2            A01           ST0001       201503   420290
# 3            A01           ST0001       201504   458431
# 4            A01           ST0001       201505   482381
# 5            A01           ST0001       201506   570412
# 6            A01           ST0001       201507   620392
# 7            A01           ST0001       201508   571781
# 8            A01           ST0001       201509   569545
# 9            A01           ST0001       201510   511679
# 10           A01           ST0001       201511   524787
# 11           A01           ST0001       201512   486509
# 12           A01           ST0001       201513   470040
# 13           A01           ST0001       201514   428195
# 14           A01           ST0001       201515   810144
# 15           A01           ST0001       201516   764927
# ...

# %%
# DB 커넥션 열기
engine2 = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# %%
# 데이터 저장
resultname='KOPO_PRODUCT_VOLUME_ST_김지성'
pdVariable.to_sql(resultname, engine2, if_exists='replace', index=False)

# %%
def excuteQuery(sql_query):
    connetcion_string = 'mssql+pymssql://haiteam:kopo1234!@192.168.110.107:1433/kopo'
    engine = create_engine(connection_string)
    
    df = pd.read_;sql(sql_query, engine)
    
    return df

# DB 테이블을 읽어 Data Frame 변수에 저장하기
storeData = executeQuery("select * from kopo_product_volume")
storeData.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-832b98642203> in <module>()
#       8
#       9 # DB 테이블을 읽어 Data Frame 변수에 저장하기
# ---> 10 storeData = executeQuery("select * from kopo_product_volume")
#      11 storeData.head()
#
# <ipython-input-8-36bf19214961> in executeQuery(sql_query)
#       6 def executeQuery(sql_query):
#       7     connetcion_string = 'mssql+pymssql://haiteam:kopo1234!@192.168.110.107:1433/kopo'
# ----> 8     engine = create_engine(connection_string)
#       9
#      10     df = pd.read_;sql(sql_query, engine)
#
# NameError: name 'connection_string' is not defined
