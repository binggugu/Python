# %% [markdown]
# ### 1. [데이터 불러오기] MYSQL에서 KOPO_PRODUCT_VOLUME 테이블을 불러온 후 ORACLE 테이블에 KOPO_PY_이름_FINAL1 테이블로 생성하세요

# %%
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:P@ssw0rd@192.168.110.112:3306/kopo')

# %%
# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM KOPO_PRODUCT_VOLUME', engine)

# %%
customerData.head()
# Out:
#   REGIONID PRODUCTGROUP YEARWEEK    VOLUME
# 0      A01       ST0002   201512  151750.0
# 1      A01       ST0001   201520  645626.0
# 2      A01       ST0002   201520  125863.0
# 3      A01       ST0001   201515  810144.0
# 4      A01       ST0002   201515  128999.0

# %%
# DB 커넥션 열기
engine2 = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# %%
resultname='KOPO_PY_김지성_FINAL1'
customerData.to_sql(resultname, engine2, if_exists='replace', index=False)

# %% [markdown]
# ### 2. [데이터 조작하기] ORACLE에서 KOPO_PRODUCT_VOLUME 테이블을 불러온 후 2016년도 자료만 남기고 ORACLE 테이블에 KOPO_PY_{이름}_FINAL2 테이블로 생성하세요

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# %%
customerData = pd.read_sql_query('SELECT * FROM kopo_product_volume', engine)

# %%
print(customerData.head())
# Out:
#   regionid productgroup yearweek    volume
# 0      A01       ST0002   201512  151750.0
# 1      A01       ST0001   201520  645626.0
# 2      A01       ST0002   201520  125863.0
# 3      A01       ST0001   201515  810144.0
# 4      A01       ST0002   201515  128999.0

# %%
answer1 = customerData[ (customerData.yearweek >= '201600') & (customerData.yearweek < '201700') ]

# %%
answer1
# Out:
#     regionid productgroup yearweek     volume
# 82       A01       ST0001   201605   661049.0
# 83       A01       ST0002   201605   231214.0
# 84       A01       ST0001   201603   531372.0
# 85       A01       ST0002   201603   152763.0
# 86       A01       ST0001   201601   651243.0
# 87       A01       ST0002   201601   162801.0
# 88       A01       ST0001   201608   671116.0
# 89       A01       ST0002   201608   130000.0
# 90       A01       ST0001   201606   881536.0
# 91       A01       ST0002   201606   172230.0
# 94       A01       ST0001   201604   585025.0
# 95       A01       ST0002   201604   197057.0
# 96       A01       ST0001   201602   573198.0
# 97       A01       ST0002   201602   137186.0
# 100      A01       ST0001   201607   790430.0
# 101      A01       ST0002   201607   161324.0
# 122      A01       ST0001   201623   768124.0
# 123      A01       ST0002   201623   161983.0
# 124      A01       ST0001   201621   721991.0
# ...

# %%
resultname='KOPO_PY_김지성_FINAL2'
answer1.to_sql(resultname, engine, if_exists='replace', index=False)

# %% [markdown]
# ### 3. [스크래핑] https://www.timeanddate.com/holidays/south-korea/ 사이트에서 화면에 보이는 테이블의 holiday정보를 스크래핑 하여 아래 이미지와 동일한 컬럼의 정보를 추출한 후 KOPO_PY_{이름}_FINAL3 테이블로 생성하세요 [심심하면 Date도 같이..저장하세요]

# %%
import requests, bs4, pandas as pd, numpy as np
from sqlalchemy import create_engine 
 
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea/')
resp.encoding='utf-8'
html = resp.text
                 
list1 = bs.select("tr > td.nw", limit=6)
print(list1)

list2 = bs.select("tr > td > a", limit=6)
print(list2)

list3 = bs.select("tr > td ", limit=6)
print(list3)
# Out:
# [<td class="nw">Monday</td>, <td class="nw">Friday</td>, <td class="nw">Wednesday</td>, <td class="nw">Thursday</td>, <td class="nw">Friday</td>, <td class="nw">Saturday</td>]
# [<a href="/holidays/southkorea/new-year-day">New Year's Day</a>, <a href="/holidays/southkorea/winter-olympics-2018">2018 Winter Olympics start</a>, <a href="/holidays/southkorea/valentines-day">Valentine's Day</a>, <a href="/holidays/southkorea/seollal-holiday-1">Seollal Holiday</a>, <a href="/holidays/southkorea/seollal-holiday-2">Seollal</a>, <a href="/holidays/southkorea/seollal-holiday-3">Seollal Holiday</a>]
# [<td class="nw">Monday</td>, <td><a href="/holidays/southkorea/new-year-day">New Year's Day</a></td>, <td>National holiday</td>, <td class="nw">Friday</td>, <td><a href="/holidays/southkorea/winter-olympics-2018">2018 Winter Olympics start</a></td>, <td>Observance</td>]

# %%
listResult = []
for flist in list1 :
    listResult.append(flist.text)
    
listResult2 = []
for flist2 in list2 :
    listResult2.append(flist2.text)    

listResult3 = []
for flist3 in list3 :
    listResult3.append(flist3.text)

# %%
df1 = pd.DataFrame(data=listResult)
df2 = pd.DataFrame(data=listResult2)
df3 = pd.DataFrame(data=listResult3)

# %%
print(df1)
print(df2)
print(df3)
# Out:
#            0
# 0     Monday
# 1     Friday
# 2  Wednesday
# 3   Thursday
# 4     Friday
# 5   Saturday
#                             0
# 0              New Year's Day
# 1  2018 Winter Olympics start
# 2             Valentine's Day
# 3             Seollal Holiday
# 4                     Seollal
# 5             Seollal Holiday
#                             0
# 0                      Monday
# 1              New Year's Day
# 2            National holiday
# 3                      Friday
# 4  2018 Winter Olympics start
# 5                  Observance

# %%
result=pd.concat([df1, df2, df3], axis=1)
result.columns= ["WEEK", "HOLIDAY_NAME", "HOLIDAY_TYPE"]
print(result)
# Out:
#         WEEK                HOLIDAY_NAME                HOLIDAY_TYPE
# 0     Monday              New Year's Day                      Monday
# 1     Friday  2018 Winter Olympics start              New Year's Day
# 2  Wednesday             Valentine's Day            National holiday
# 3   Thursday             Seollal Holiday                      Friday
# 4     Friday                     Seollal  2018 Winter Olympics start
# 5   Saturday             Seollal Holiday                  Observance

# %%
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# %%
resultname='KOPO_PY_김지성_FINAL3'
result.to_sql(resultname, engine, if_exists='replace', index=False)

# %%
pwd
# Out:
# 'C:\\Users\\SMART-20\\Python Session\\기타.기말고사'
